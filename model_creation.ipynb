# %% [markdown]
# # Emotion Detection

# %% [markdown]
# **Importing Libraries**

# %%
import matplotlib.pyplot as plt
from glob import glob
import cv2
import random
import os
# %matplotlib inline

from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import Dense, Input, Dropout, Flatten, Conv2D
from tensorflow.keras.layers import BatchNormalization, Activation, MaxPooling2D
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau
from tensorflow.keras.utils import plot_model

from IPython.display import SVG, Image
import tensorflow as tf
print("Tensorflow version:", tf.__version__)
# Out:
# Tensorflow version: 2.16.1

# %% [markdown]
# **Exploring Dataset**

# %%
images = glob("train/**/**")
for i in range(9):
    image = random.choice(images)
    plt.figure(figsize=(12,12))
    plt.subplot(331+i)
    plt.imshow(cv2.imread(image));plt.axis('off')

# %% [markdown]
# **Preparing Data for Training**

# %%
img_size = 48
batch_size = 64
datagen_train = ImageDataGenerator()
train_generator = datagen_train.flow_from_directory("train/",
                                                   target_size = (img_size,img_size),
                                                   color_mode = "grayscale",
                                                   batch_size = batch_size,
                                                   class_mode = "categorical",
                                                   shuffle = True)

datagen_validation = ImageDataGenerator()
validation_generator = datagen_train.flow_from_directory("test/",
                                                   target_size = (img_size,img_size),
                                                   color_mode = "grayscale",
                                                   batch_size = batch_size,
                                                   class_mode = "categorical",
                                                   shuffle = True)
# Out:
# Found 28709 images belonging to 7 classes.
# Found 7178 images belonging to 7 classes.

# %% [markdown]
# **Defining Model**

# %%
def Convolution(input_tensor, filters, kernel_size):
    x = Conv2D(filters = filters, kernel_size = kernel_size, padding = "same")(input_tensor)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = MaxPooling2D(pool_size = (2,2))(x)
    x = Dropout(0.25)(x)
    
    return x

# %%
def Dense_f(input_tensor, nodes):
    x = Dense(nodes)(input_tensor)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = Dropout(0.25)(x)
    
    return x

# %%
def model_fer(input_shape):
    inputs = Input(input_shape)
    conv_1 = Convolution(inputs,32,(3,3))
    conv_2 = Convolution(conv_1,64,(5,5))
    conv_3 = Convolution(conv_2,128,(3,3))

    flatten = Flatten()(conv_3)
    
    dense_1 = Dense_f(flatten,256)

    output  = Dense(7, activation="softmax")(dense_1)
    model  =  Model(inputs=[inputs],outputs = [output])
    
    model.compile(loss=['categorical_crossentropy'] , optimizer = 'adam' , metrics =["accuracy"])

    return model

# %%
model = model_fer((48,48,1))
model.summary()
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 48, 48, 1)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d (Conv2D)                 │ (None, 48, 48, 32)     │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 48, 48, 32)     │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation (Activation)         │ (None, 48, 48, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 24, 24, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 24, 24, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 24, 24, 64)     │        51,264 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 24, 24, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_1 (Activation)       │ (None, 24, 24, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 12, 12, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 12, 12, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 12, 12, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 12, 12, 128)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_2 (Activation)       │ (None, 12, 12, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 6, 6, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 6, 6, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 4608)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 256)            │     1,179,904 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_3           │ (None, 256)            │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_3 (Activation)       │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 7)              │         1,799 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,309,063 (4.99 MB)
#  Trainable params: 1,308,103 (4.99 MB)
#  Non-trainable params: 960 (3.75 KB)

# %% [markdown]
# **Initializing the Model**

# %%
epochs = 15
steps_per_epoch = train_generator.n//train_generator.batch_size
validation_steps = validation_generator.n//validation_generator.batch_size

checkpoint = ModelCheckpoint("model_weights.weights.h5", monitor  ='val_accuracy', save_weights_only = True, mode = 'max', verbose =1)
callbacks = [checkpoint]

# %% [markdown]
# # Traning the Model

# %% [markdown]
# **The next cell takes time to complete**

# %%
history = model.fit(
x = train_generator,
steps_per_epoch = steps_per_epoch,
epochs = epochs,
validation_data = validation_generator,
validation_steps = validation_steps,
callbacks = callbacks)
# Out:
# Epoch 1/15
# C:\Users\hp\AppData\Roaming\Python\Python312\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:120: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 916ms/step - accuracy: 0.3137 - loss: 1.8204
# Epoch 1: saving model to model_weights.weights.h5
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 498s 1s/step - accuracy: 0.3139 - loss: 1.8201 - val_accuracy: 0.4007 - val_loss: 1.6177
# Epoch 2/15
#   1/448 ━━━━━━━━━━━━━━━━━━━━ 2:46 373ms/step - accuracy: 0.4062 - loss: 1.4681
# Epoch 2: saving model to model_weights.weights.h5
# c:\Program Files\Python312\Lib\contextlib.py:158: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self.gen.throw(value)
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 1s 610us/step - accuracy: 0.4062 - loss: 1.4681 - val_accuracy: 0.3000 - val_loss: 1.5280
# Epoch 3/15
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 339ms/step - accuracy: 0.4603 - loss: 1.4015
# Epoch 3: saving model to model_weights.weights.h5
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 160s 356ms/step - accuracy: 0.4604 - loss: 1.4014 - val_accuracy: 0.5018 - val_loss: 1.2985
# Epoch 4/15
#   1/448 ━━━━━━━━━━━━━━━━━━━━ 2:34 345ms/step - accuracy: 0.5156 - loss: 1.2606
# Epoch 4: saving model to model_weights.weights.h5
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 276us/step - accuracy: 0.5156 - loss: 1.2606 - val_accuracy: 0.5000 - val_loss: 1.3687
# Epoch 5/15
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 331ms/step - accuracy: 0.5197 - loss: 1.2700
# Epoch 5: saving model to model_weights.weights.h5
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 156s 348ms/step - accuracy: 0.5197 - loss: 1.2700 - val_accuracy: 0.5006 - val_loss: 1.2840
# Epoch 6/15
#   1/448 ━━━━━━━━━━━━━━━━━━━━ 2:29 335ms/step - accuracy: 0.5781 - loss: 1.0128
# Epoch 6: saving model to model_weights.weights.h5
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 325us/step - accuracy: 0.5781 - loss: 1.0128 - val_accuracy: 0.7000 - val_loss: 1.2466
# Epoch 7/15
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 332ms/step - accuracy: 0.5507 - loss: 1.1861
# Epoch 7: saving model to model_weights.weights.h5
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 157s 349ms/step - accuracy: 0.5507 - loss: 1.1861 - val_accuracy: 0.5144 - val_loss: 1.3030
# Epoch 8/15
#   1/448 ━━━━━━━━━━━━━━━━━━━━ 2:28 332ms/step - accuracy: 0.5156 - loss: 1.2728
# Epoch 8: saving model to model_weights.weights.h5
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 1s 412us/step - accuracy: 0.5156 - loss: 1.2728 - val_accuracy: 0.5000 - val_loss: 1.4267
# Epoch 9/15
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 333ms/step - accuracy: 0.5707 - loss: 1.1381
# Epoch 9: saving model to model_weights.weights.h5
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 157s 351ms/step - accuracy: 0.5707 - loss: 1.1381 - val_accuracy: 0.5233 - val_loss: 1.2756
# Epoch 10/15
#   1/448 ━━━━━━━━━━━━━━━━━━━━ 2:34 345ms/step - accuracy: 0.5156 - loss: 1.2745
# Epoch 10: saving model to model_weights.weights.h5
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 300us/step - accuracy: 0.5156 - loss: 1.2745 - val_accuracy: 0.3000 - val_loss: 1.5084
# Epoch 11/15
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 333ms/step - accuracy: 0.5910 - loss: 1.0813
# Epoch 11: saving model to model_weights.weights.h5
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 157s 350ms/step - accuracy: 0.5910 - loss: 1.0813 - val_accuracy: 0.5300 - val_loss: 1.2368
# Epoch 12/15
#   1/448 ━━━━━━━━━━━━━━━━━━━━ 2:04 279ms/step - accuracy: 0.6562 - loss: 1.0171
# Epoch 12: saving model to model_weights.weights.h5
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 267us/step - accuracy: 0.6562 - loss: 1.0171 - val_accuracy: 0.7000 - val_loss: 0.8886
# Epoch 13/15
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 313ms/step - accuracy: 0.6095 - loss: 1.0330
# Epoch 13: saving model to model_weights.weights.h5
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 148s 329ms/step - accuracy: 0.6095 - loss: 1.0330 - val_accuracy: 0.5607 - val_loss: 1.1688
# Epoch 14/15
#   1/448 ━━━━━━━━━━━━━━━━━━━━ 2:25 325ms/step - accuracy: 0.6875 - loss: 1.0044
# Epoch 14: saving model to model_weights.weights.h5
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 330us/step - accuracy: 0.6875 - loss: 1.0044 - val_accuracy: 0.7000 - val_loss: 1.0321
# Epoch 15/15
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 320ms/step - accuracy: 0.6251 - loss: 1.0066
# Epoch 15: saving model to model_weights.weights.h5
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 151s 337ms/step - accuracy: 0.6251 - loss: 1.0066 - val_accuracy: 0.5638 - val_loss: 1.1819

# %% [markdown]
# **Model Evaluation**

# %%
model.evaluate(validation_generator)
# Out:
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 9s 79ms/step - accuracy: 0.5646 - loss: 1.1869
# [1.182000756263733, 0.5635274648666382]

# %% [markdown]
# **Plotting Loss**

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.legend(['Train','Validation'],loc = 'upper left')
plt.subplots_adjust(top=1.0,bottom=0.0,right =0.95,left=0.0,hspace=0.25,wspace=0.35)

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.legend(['Train','Validation'],loc = 'upper left')
plt.subplots_adjust(top=1.0,bottom=0.0,right =0.95,left=0.0,hspace=0.25,wspace=0.35)

# %% [markdown]
# **Saving Model**

# %%
model_json = model.to_json()
with open("model_a.json","w") as json_file:
    json_file.write(model_json)
